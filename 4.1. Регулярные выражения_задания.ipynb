# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %% [markdown]
# 🔹 **Задание 1. Разбить строку на список чистых слов/словосочетаний без символов**

# %%
import re

# %%
text = "Nice!Good job#Well done- Perfect"

# %%
cleaned_text = re.split(r"[!#-]", text)

# %%
print(cleaned_text)
# Out:
# ['Nice', 'Good job', 'Well done', ' Perfect']

# %% [markdown]
# 🔹 **Задание 2. Замаскировать только последние четыре цифры номера карты на звездочки**

# %%
text = "Номер карты: 1234 5678 9012 3456"

# %%
sub = re.sub(r"\d{4} \d{4} \d{4} \d{4}", r"1234 5678 9012 ****", text)

# %%
sub
# Out:
# 'Номер карты: 1234 5678 9012 ****'

# %% [markdown]
# 🔹 **Задание 3. Вывести только первую фамилию с окончанием "ий"**

# %%
text = "В списке фамилий были Иванов, Яновский и Васильев"

# %%
search=re.search(r"[А-ЯЁ][а-яё]+ий", text)
search
# Out:
# <re.Match object; span=(30, 38), match='Яновский'>

# %% [markdown]
# 🔹 **Задание 4. Вывести весь текст между комментариями, то есть между звездочками**
#
# Примечание: не забыть, что нужно экранировать некоторые симолвы (обратный слэш)

# %%
text = "код * исправить вот здесь! добавить проверку * продолжение"

# %%
search = re.search(r"*\s(.*)\s*", text)
# Out:
# ---------------------------------------------------------------------------
# PatternError                              Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 search = re.search(r"*\s(.*)\s*", text)
#
# File ~\anaconda3\Lib\re\__init__.py:177, in search(pattern, string, flags)
#     174 def search(pattern, string, flags=0):
#     175     """Scan through string looking for a match to the pattern, returning
#     176     a Match object, or None if no match was found."""
# --> 177     return _compile(pattern, flags).search(string)
#
# File ~\anaconda3\Lib\re\__init__.py:350, in _compile(pattern, flags)
#     348 if not _compiler.isstring(pattern):
#     349     raise TypeError("first argument must be string or compiled pattern")
# --> 350 p = _compiler.compile(pattern, flags)
#     351 if flags & DEBUG:
#     352     return p
#
# File ~\anaconda3\Lib\re\_compiler.py:748, in compile(p, flags)
#     746 if isstring(p):
#     747     pattern = p
# --> 748     p = _parser.parse(p, flags)
#     749 else:
#     750     pattern = None
#
# File ~\anaconda3\Lib\re\_parser.py:980, in parse(str, flags, state)
#     977 state.flags = flags
#     978 state.str = str
# --> 980 p = _parse_sub(source, state, flags & SRE_FLAG_VERBOSE, 0)
#     981 p.state.flags = fix_flags(str, p.state.flags)
#     983 if source.next is not None:
#
# File ~\anaconda3\Lib\re\_parser.py:459, in _parse_sub(source, state, verbose, nested)
#     457 start = source.tell()
#     458 while True:
# --> 459     itemsappend(_parse(source, state, verbose, nested + 1,
#     460                        not nested and not items))
#     461     if not sourcematch("|"):
#     462         break
#
# File ~\anaconda3\Lib\re\_parser.py:686, in _parse(source, state, verbose, nested, first)
#     684     item = None
#     685 if not item or item[0][0] is AT:
# --> 686     raise source.error("nothing to repeat",
#     687                        source.tell() - here + len(this))
#     688 if item[0][0] in _REPEATCODES:
#     689     raise source.error("multiple repeat",
#     690                        source.tell() - here + len(this))
#
# PatternError: nothing to repeat at position 0

# %%
print(search.group(0))
# Out:
# ий

# %% [markdown]
# 🔹 **Задание 5. Вывести все цены из текста**
#
# Примечание: цена может быть из любого количество цифр и может быть указана с копейками, то есть от 1 до 2 знаков после точки

# %%
text = "Количество: 5 штук. Цена: 199.90 рублей. Завтра будет цена: 220 рублей"

# %%
findall = re.findall(r"\d{3}.\d{2}|\d{3}", text)

# %%
findall
# Out:
# ['199.90', '220']
